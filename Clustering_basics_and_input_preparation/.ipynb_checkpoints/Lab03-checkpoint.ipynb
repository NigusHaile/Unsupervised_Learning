# %%
import os
import io
import matplotlib as plt
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df = pd.read_csv('\\wsl.localhost\Ubuntu-22.04\home\nigus\EDU\Unsupervised\Lab\Lab03')
